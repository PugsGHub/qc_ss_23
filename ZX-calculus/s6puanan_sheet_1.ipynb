# %% [markdown]
# # Exercises for Introduction to Quantum Computing

# %% [markdown]
# Name: Pugazharasu Anancia Devaneyan (s6puanan)
# Matriculation number: 3300280

# %% [markdown]
# ## 1. Installation of Qiskit

# %%
# %pip install pyzx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys; sys.path.insert(0, '..')
import random
import pyzx as zx
from fractions import Fraction
from ipywidgets import widgets
from IPython.display import display, Markdown
from pyzx.simplify import clifford_iter

# %% [markdown]
# ## 2. Quantum Gates

# %%
#

# %% [markdown]
# ### 3. Hadamard identity

# %%
def hadamard_gate():
    return

# %%
hadamard_1 = zx.Graph()
h_i_1 = hadamard_1.add_vertex(0, 0, 0, Fraction(0))

h_i_2 = hadamard_1.add_vertex(0, 1, 0, Fraction(0))

h_r = hadamard_1.add_vertex(1, 0, 1, Fraction(1/2))
h_s = hadamard_1.add_vertex(2, 0, 2, Fraction(1/2))
h_t = hadamard_1.add_vertex(1, 0, 3, Fraction(1/2))

h_a = hadamard_1.add_vertex(1, 0, 4, Fraction(0))

h_b = hadamard_1.add_vertex(2, 1, 4, Fraction(0))

d_r = hadamard_1.add_vertex(1, 0, 5, Fraction(1/2))
d_s = hadamard_1.add_vertex(2, 0, 6, Fraction(1/2))
d_t = hadamard_1.add_vertex(1, 0, 7, Fraction(1/2))

h_e_1 = hadamard_1.add_vertex(0, 0, 8, Fraction(0))

h_e_2 = hadamard_1.add_vertex(0, 1, 8, Fraction(0))


hadamard_1.add_edges([(h_i_1, h_r),(h_r,h_s),(h_s,h_t),(h_t,h_a),(h_i_2,h_b),(h_a,h_b),(h_a,d_r),(d_r,d_s),(d_s,d_t),(d_t,h_e_1),(h_b,h_e_2)])
zx.draw_matplotlib(hadamard_1, labels=True)

# %%
#g = hadamard_1.to_graph()
zx.clifford_simp(hadamard_1)
hadamard_1.normalize()
zx.draw_matplotlib(hadamard_1, labels=True)
